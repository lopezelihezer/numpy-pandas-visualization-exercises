# %% [markdown]
# 1. Use matplotlib to plot the following equation: y=x2−x+2
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt
from random import randint
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
import numpy as np
import pandas as pd

x = pd.Series(range(0, 50)) # or some other range of numbers for your x values
def squared_minus_x_plus_two(x):
    return x**2 - x + 2
y = x.apply(squared_minus_x_plus_two)

# %%
plt.plot(y)
plt.text(0, 2, 'the origin', fontsize=10, color='blue', rotation=45)
plt.ylim(0, 20)
plt.xlim(0, 20)
plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#     - y = sqrt(x)
#     - y = x**3
#     - y = 2**x
#     - y = 1/(x+1)
#
# ### You can use the functions from the math module to help implement some of the equations above.

# %%
import math

# %%
n_rows = 2
n_cols = 2

x = pd.Series(range(0, 10))

y1 = x.apply(lambda x: math.isqrt(x))
y2 = x**3
y3 = 2**x
y4 = 1/(x+1)

plt.subplot(n_rows, n_cols, 1)
plt.plot(x, y1)
plt.title('x ~ y1')

# the second subplot
plt.subplot(n_rows, n_cols, 2)
plt.plot(x, y2)
plt.title('x ~ y2')

plt.subplot(n_rows, n_cols, 3)
plt.plot(x, y3)
plt.title('x ~ y3')

# the second subplot
plt.subplot(n_rows, n_cols, 4)
plt.plot(x, y4)
plt.title('x ~ y4')

plt.tight_layout()
plt.suptitle('Different Ys')
plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(12, 5))

n_rows = 2
n_cols = 2

x = pd.Series(range(0, 10))

y1 = x.apply(lambda x: math.isqrt(x))
y2 = x**3
y3 = 2**x
y4 = 1/(x+1)

plt.subplot(n_rows, n_cols, 1)
plt.plot(x, y1)
plt.title('x ~ y1')

# the second subplot
plt.subplot(n_rows, n_cols, 2)
plt.plot(x, y2)
plt.title('x ~ y2')

plt.subplot(n_rows, n_cols, 3)
plt.plot(x, y3)
plt.title('x ~ y3')

# the second subplot
plt.subplot(n_rows, n_cols, 4)
plt.plot(x, y4)
plt.title('x ~ y4')

plt.tight_layout()
plt.suptitle('Different Ys')
plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize=(12, 5))

n_rows = 2
n_cols = 2

x = pd.Series(range(0, 10))

y1 = x.apply(lambda x: math.isqrt(x))
y2 = x**3
y3 = 2**x
y4 = 1/(x+1)

plt.subplot(n_rows, n_cols, 1)
plt.plot(x, y1, color='red')
plt.title('x ~ y1')

plt.subplot(n_rows, n_cols, 2)
plt.plot(x, y2, color='green')
plt.title('x ~ y2')

plt.subplot(n_rows, n_cols, 3)
plt.plot(x, y3, color='yellow')
plt.title('x ~ y3')

plt.subplot(n_rows, n_cols, 4)
plt.plot(x, y4, color='purple')
plt.title('x ~ y4')


plt.tight_layout()
plt.suptitle('Different Ys')
plt.show()

# %%
# Example given by Ryan

x = list(range(0, 25))

# generate y for each fucntion
y1 = [math.sqrt(n) for n in x]
y2 = [n**3 for n in x]
y3 = [2**n for n in x]
y4 = [1/(n+1) for n in x]

plt.plot(x, y1, c='#30a2da', label='$\sqrt{x}$', alpha=1.0)
plt.plot(x, y2, c='orange', label='$x^{3}$', alpha=.8)
plt.plot(x, y3, c= (1,0,1), label='$2^{x}$', alpha=.8)
plt.plot(x, y4, c= '#444444', label='$1/(x+1)$', alpha=.8)


plt.ylim(0, 10)
plt.xlim(0, 10)

plt.ylabel('$y$')
plt.xlabel('$x$')
plt.title('My Functions')
plt.legend()

plt.show()
